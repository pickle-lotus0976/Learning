# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Pandas Dataframe
# It is a 2-D tabular data structure consisting of rows and columns (kind of like a table). It is a collection of many Series

# %% [markdown]
# # Creating Dataframes

# %%
# using list
student_data = [
    [100, 80, 10],
    [180, 100, 30],
    [80, 90, 40]
]
students = pd.DataFrame(student_data, columns=['IQ', 'Marks', 'Package'])
print(students)
# Out:
#     IQ  Marks  Package
# 0  100     80       10
# 1  180    100       30
# 2   80     90       40

# %%
# using dict
students_dict = {
    'Name': ['Rohan', 'Shivam', 'Ankit', 'Hari', 'Jim', 'Puja'],
    'IQ': [100, 180, 80, 0, 0, 0],
    'Marks': [80, 100, 90, 0, 0, 0],
    'Package': [10, 30, 40, 0, 0, 0]
}
perform = pd.DataFrame(students_dict)
perform.set_index('Name', inplace=True)

# %%
# using read_csv
movies = pd.read_csv('/content/movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl = pd.read_csv('/content/ipl-matches.csv')
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# # Dataframe Attributes

# %%
# shape
print(movies.shape)
print(ipl.shape)
# Out:
# (1629, 18)
# (950, 20)

# %%
# dtypes
# Gives the datatypes and names of all the columns in the tabular dataframe
# Index -> Column name
# Value -> Datatype
print(movies.dtypes)
print('\n', ipl.dtypes)
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object
#
#  ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# ...

# %%
# index
print(ipl.index)
print('\n', movies.index)
# Out:
# RangeIndex(start=0, stop=950, step=1)
#
#  RangeIndex(start=0, stop=1629, step=1)

# %%
# columns
print(ipl.columns)
print('\n', movies.columns)
print('\n', students.columns)
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')
#
#  Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')
#
#  Index(['IQ', 'Marks', 'Package'], dtype='object')

# %%
# values
print(ipl.values)
print('\n', movies.values)
print('\n', students.values)
# Out:
# [[1312200 'Ahmedabad' '2022-05-29' ...
#   "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']"
#   'CB Gaffaney' 'Nitin Menon']
#  [1312199 'Ahmedabad' '2022-05-27' ...
#   "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']"
#   'CB Gaffaney' 'Nitin Menon']
#  [1312198 'Kolkata' '2022-05-25' ...
#   "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']"
#   'J Madanagopal' 'MA Gough']
#  ...
#  [335984 'Delhi' '2008-04-19' ...
#   "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']"
#   'Aleem Dar' 'GA Pratapkumar']
#  [335983 'Chandigarh' '2008-04-19' ...
# ...

# %%
# head and tail
movies.tail(3)
# Out:
#               title_x     imdb_id  \
# 1626  Sabse Bada Sukh   tt0069204
# 1627            Daaka  tt10833860
# 1628         Humsafar   tt2403201
#
#                                             poster_path  \
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link          title_y  \
# 1626  https://en.wikipedia.org/wiki/Sabse_Bada_Sukh  Sabse Bada Sukh
# 1627            https://en.wikipedia.org/wiki/Daaka            Daaka
# 1628         https://en.wikipedia.org/wiki/Humsafar         Humsafar
#
#        original_title  is_adult  year_of_release runtime         genres  \
# 1626  Sabse Bada Sukh         0             2018      \N   Comedy|Drama
# 1627            Daaka         0             2019     136         Action
# 1628         Humsafar         0             2011      35  Drama|Romance
#
# ...

# %%
ipl.tail()
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
# sample
movies.sample()
# Out:
#        title_x    imdb_id                                        poster_path  \
# 586  Jolly LLB  tt2621000  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                    wiki_link    title_y original_title  \
# 586  https://en.wikipedia.org/wiki/Jolly_LLB  Jolly LLB      Jolly LLB
#
#      is_adult  year_of_release runtime        genres  imdb_rating  imdb_votes  \
# 586         0             2013     135  Comedy|Drama          7.5       15157
#
#                                                  story  \
# 586  Rajpal a top lawyer is defending Rahul Dewan s...
#
#                                                summary               tagline  \
# 586  A small time lawyer files a PIL in court again...  We Believe InJustice
#
#                                                 actors  \
# 586  Arshad Warsi|Amrita Rao|Boman Irani|Saurabh Sh...
#
#            wins_nominations           release_date
# 586  7 wins & 5 nominations  15 March 2013 (India)

# %%
ipl.sample(5)
# Out:
#           ID       City        Date   Season MatchNumber  \
# 79   1254088  Abu Dhabi  2021-10-08     2021          55
# 899   336035    Kolkata  2008-05-25  2007/08          52
# 38   1304082     Mumbai  2022-04-23     2022          36
# 354  1082608      Delhi  2017-04-17     2017          18
# 762   501210     Mumbai  2011-04-15     2011          13
#
#                            Team1                  Team2  \
# 79                Mumbai Indians    Sunrisers Hyderabad
# 899        Kolkata Knight Riders        Kings XI Punjab
# 38   Royal Challengers Bangalore    Sunrisers Hyderabad
# 354             Delhi Daredevils  Kolkata Knight Riders
# 762               Mumbai Indians   Kochi Tuskers Kerala
#
#                                 Venue            TossWinner TossDecision  \
# 79   Zayed Cricket Stadium, Abu Dhabi        Mumbai Indians          bat
# 899                      Eden Gardens       Kings XI Punjab          bat
# ...

# %%
# info
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
# describe
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
# isnull
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
# duplicated
ipl.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
perform.duplicated()
# Out:
# Name
# Rohan     False
# Shivam    False
# Ankit     False
# Hari      False
# Jim        True
# Puja       True
# dtype: bool

# %%
perform.duplicated().sum()
# Out:
# np.int64(2)

# %%
perform
# Out:
#          IQ  Marks  Package
# Name
# Rohan   100     80       10
# Shivam  180    100       30
# Ankit    80     90       40
# Hari      0      0        0
# Jim       0      0        0
# Puja      0      0        0

# %%
# rename
perform.rename(columns={'marks':'percentage', 'package':'lpa'}, inplace=True)
perform
# Out:
#          IQ  Marks  Package
# Name
# Rohan   100     80       10
# Shivam  180    100       30
# Ankit    80     90       40
# Hari      0      0        0
# Jim       0      0        0
# Puja      0      0        0

# %% [markdown]
# # Mathematical Functions

# %%
# sum
print(students.sum())
print(students.sum(axis=1))
# Out:
# IQ         360
# Marks      270
# Package     80
# dtype: int64
# 0    190
# 1    310
# 2    210
# dtype: int64

# %%
# max/min
print(students.max())
print(students.min())
# Out:
# IQ         180
# Marks      100
# Package     40
# dtype: int64
# IQ         80
# Marks      80
# Package    10
# dtype: int64

# %%
# mean
print(students.mean())
# median
print(students.median())
# sd
print(students.std(axis=1))
# var
print(students.var(axis=1))
# Out:
# IQ         120.000000
# Marks       90.000000
# Package     26.666667
# dtype: float64
# IQ         100.0
# Marks       90.0
# Package     30.0
# dtype: float64
# 0    47.258156
# 1    75.055535
# 2    26.457513
# dtype: float64
# 0    2233.333333
# 1    5633.333333
# 2     700.000000
# dtype: float64

# %% [markdown]
# # Selecting a single column

# %%
movies['title_x']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
ipl['Venue']
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
# multiple columns
print(type(movies[['title_x', 'year_of_release', 'actors']]))
movies[['year_of_release', 'actors', 'title_x']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
#       year_of_release                                             actors  \
# 0                2019  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1                2019  Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2                2019  Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3                2019  Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4                2018  Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
# ...               ...                                                ...
# 1624             2001  Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# 1625             2001  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1626             2018  Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...
# 1627             2019                          Gippy Grewal|Zareen Khan|
# 1628             2011                                        Fawad Khan|
#
#                                    title_x
# ...

# %%
ipl[['Team1', 'Team2', 'WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %% [markdown]
# # Selecting Rows
# * **iloc:** searches using index positions
# * **loc:** searches using index labels

# %%
# single row
movies.iloc[5]
# Out:
# title_x                                                   Soni (film)
# imdb_id                                                     tt6078866
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link                   https://en.wikipedia.org/wiki/Soni_(film)
# title_y                                                          Soni
# original_title                                                   Soni
# is_adult                                                            0
# year_of_release                                                  2018
# runtime                                                            97
# genres                                                          Drama
# imdb_rating                                                       7.2
# imdb_votes                                                       1595
# story               Soni  a young policewoman in Delhi  and her su...
# ...

# %%
movies.iloc[0:5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
movies.iloc[::-5]
# Out:
#                                title_x    imdb_id  \
# 1628                          Humsafar  tt2403201
# 1623                          Zubeidaa  tt0255713
# 1618                      Rahul (film)  tt0277981
# 1613                         Paagalpan  tt0285319
# 1608                        One 2 Ka 4  tt0227194
# ...                                ...        ...
# 23                Notebook (2019 film)  tt9105014
# 18                   Photograph (film)  tt7778680
# 13                       Total Dhamaal  tt7639372
# 8     Manikarnika: The Queen of Jhansi  tt6903440
# 3                      Why Cheat India  tt8108208
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1618  https://upload.wikimedia.org/wikipedia/en/f/f8...
# 1613  https://upload.wikimedia.org/wikipedia/en/thum...
# 1608  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.iloc[[0,4,5]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
movies.iloc[1:10:2]
# Out:
#             title_x    imdb_id  \
# 1     Battalion 609  tt9472208
# 3   Why Cheat India  tt8108208
# 5       Soni (film)  tt6078866
# 7        Bombairiya  tt4971258
# 9  Thackeray (film)  tt7777196
#
#                                          poster_path  \
# 1                                                NaN
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
# 7  https://upload.wikimedia.org/wikipedia/en/thum...
# 9  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                         wiki_link          title_y  \
# 1     https://en.wikipedia.org/wiki/Battalion_609    Battalion 609
# 3   https://en.wikipedia.org/wiki/Why_Cheat_India  Why Cheat India
# 5       https://en.wikipedia.org/wiki/Soni_(film)             Soni
# 7        https://en.wikipedia.org/wiki/Bombairiya       Bombairiya
# 9  https://en.wikipedia.org/wiki/Thackeray_(film)        Thackeray
#
# ...

# %%
perform
# Out:
#          IQ  Marks  Package
# Name
# Rohan   100     80       10
# Shivam  180    100       30
# Ankit    80     90       40
# Hari      0      0        0
# Jim       0      0        0
# Puja      0      0        0

# %%
perform.loc['Rohan']
# Out:
# IQ         100
# Marks       80
# Package     10
# Name: Rohan, dtype: int64

# %%
perform.loc['Rohan':'Puja']
# Out:
#          IQ  Marks  Package
# Name
# Rohan   100     80       10
# Shivam  180    100       30
# Ankit    80     90       40
# Hari      0      0        0
# Jim       0      0        0
# Puja      0      0        0

# %%
perform.loc['Rohan':'Puja':2]
# Out:
#         IQ  Marks  Package
# Name
# Rohan  100     80       10
# Ankit   80     90       40
# Jim      0      0        0

# %% [markdown]
# # Selecting rows and columns

# %%
movies.iloc[0:3, 0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:2, 'title_x':'poster_path']
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# # Filtering the Dataframe

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
# find all the final winners
new_df = ipl[ipl['MatchNumber'] == 'Final']
new_df[['Season', 'WinningTeam']]
# ipl[ipl['MatchNumber'] == 'Final'][['Season', 'WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# how many super overs finishes have occured
ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
# toss winner is match winner in percentage
# ipl[ipl['TossWinner'] == ipl['WinningTeam']][['TossWinner', 'WinningTeam']]
percent = (ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0]) * 100
print(percent)
# Out:
# 51.473684210526315

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
# action movies with ratings over 7.5
# wrong method: movies[(movies['imdb_rating'] > 7.5 ) & (movies['genres'] == 'Action')][['title_x', 'imdb_rating', 'genres']]
# mask1 = movies['genres'].str.split('|').apply(lambda x: 'Action' in x) # Checks whether the list contains the word "Action" or not
mask2 = movies['imdb_rating'] > 7.5
mask1 = movies['genres'].str.contains('Action')
print(movies[mask1 & mask2].shape[0])
movies[mask1 & mask2][['title_x', 'genres', 'imdb_rating']]
# Out:
# 33
#                             title_x                   genres  imdb_rating
# 0          Uri: The Surgical Strike         Action|Drama|War          8.4
# 41             Family of Thakurganj             Action|Drama          9.4
# 84                        Mukkabaaz       Action|Drama|Sport          8.1
# 106                           Raazi    Action|Drama|Thriller          7.8
# 110   Parmanu: The Story of Pokhran     Action|Drama|History          7.7
# 112         Bhavesh Joshi Superhero             Action|Drama          7.6
# 169                The Ghazi Attack      Action|Thriller|War          7.6
# 219                Raag Desh (film)     Action|Drama|History          8.3
# 258                   Irudhi Suttru       Action|Drama|Sport          7.6
# 280                       Laal Rang       Action|Crime|Drama          8.0
# 297                     Udta Punjab       Action|Crime|Drama          7.8
# 354                   Dangal (film)   Action|Biography|Drama          8.4
# ...

# %%
# movies with a rating greater than 8 and votes > 10000
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %%
# how many matches has CSK won in Kolkata
ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
# write a function that can track record of 2 teams against each other

# %% [markdown]
# # Adding new colums

# %%
# completly new
movies['Country'] = 'India'
movies.head(10)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
# 5                           Soni (film)  tt6078866
# 6                         Fraud Saiyaan  tt5013008
# 7                            Bombairiya  tt4971258
# 8      Manikarnika: The Queen of Jhansi  tt6903440
# 9                      Thackeray (film)  tt7777196
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# existing columns
# movies.dropna(inplace=True)
movies['lead_actor'] = movies['actors'].fillna('').str.split('|').apply(lambda x: x[0])
movies.head(10)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
# 5                           Soni (film)  tt6078866
# 6                         Fraud Saiyaan  tt5013008
# 7                            Bombairiya  tt4971258
# 8      Manikarnika: The Queen of Jhansi  tt6903440
# 9                      Thackeray (film)  tt7777196
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['ID'] = ipl['ID'].astype('int32')
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['Season'] = ipl['Season'].astype('category')
ipl['Team1'] = ipl['Team1'].astype('category')
ipl['Team2'] = ipl['Team2'].astype('category')
ipl['WinningTeam'] = ipl['WinningTeam'].astype('category')
ipl['Venue'] = ipl['Venue'].astype('category')
ipl['TossWinner'] = ipl['TossWinner'].astype('category')
ipl['TossDecision'] = ipl['TossDecision'].astype('category')
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    category
#  8   TossWinner       950 non-null    category
#  9   TossDecision     950 non-null    category
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    category
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...
